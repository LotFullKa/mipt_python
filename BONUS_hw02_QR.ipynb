# %% [markdown]
# <div style="text-align: center; padding: 30px 10px;">
#
# <h2 style="font-size: 30px; margin-top: 5px;">
# Бонусная лабораторная работа 2. Легенда о QR разложении.
# </h2>
#
# <hr style="width: 60%; border: 1px solid #10069f; margin: 25px auto;">
#
# </div>
#
# Если Вы видите <b><font color="#FF69B4"> Ваш ответ здесь </font></b> - надо поменять текст внутри блока на свой текстовый ответ на вопрос.
#
#
# ВАЖНО! Здесь и далее от вас ожидается чистый код, близкий к тому, что нужно в индустрии. В контексте данной лабораторной работы ожидаются корректные названия у полей, методов и переменных, которые вы вводите; корректная инкапсуляция - нижнее подчеркивание или два перед названием метода или атрибута. Для корректной инкапсуляции можно (и даже нужно) добавлять нижние подчеркивания даже к названиям методов/атрибутов из условий задач :)
#
#
#
# **ВАЖНО!!** Везде в этой лабе нужно использовать **корректные type hints**

# %% [markdown]
# # 1. `QR` wounds (2 балла для основы, 0 для остальных потоков).

# %% [markdown]
# Что такое QR разложение? Зачем оно нужно?
#
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# Напиши код своего собственного QR разложения через ортогонализацию Грамма-Шмидта и сравни его по времени и точности с кодом QR разложения `np.linalg.qr`.

# %%
# TODO

# %% [markdown]
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# # 2. Detect thoughts (1 балл)

# %% [markdown]
# Что такое BLAS и LAPACK? Какое отношение они имеют к текущему алгоритму и библиотекам NumPy, PyTorch?
#
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# Ты реализовал уже некий алгоритм. Какое главное препятствие к его параллелизации?
#
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# Изучи способы разбиения classical Gramm-Schmidt на независимые подзадачи. Какие ты можешь применить?
#
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# Изучи classical Gramm-Schmidt и modified Gramm-Schmidt. В чём разница? А в контексте параллелизации?
#
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# ## 3. Modify Memory (3 балла)
#
# Реализуй modified Gramm-Shmidt и примени его в QR разложении.
#
# Сравни с алгоритмом из п. 1. Какой лучше по времени, точности?

# %%
# TODO

# %% [markdown]
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# ## 4. Sending (3 балла - для основы, ДПО и продвинутого потоков)
#
# Перенеси свой алгоритм из п. 1 или п. 3 (на выбор) на PyTorch с полноценным применением CUDA.
#
# Сравни по времени и точности с алгоритмами из п. 1 (или 3).

# %%
# TODO

# %% [markdown]
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# Запусти трейсы для своего алгоритма и прикрепи их к итоговому решению + вставь скриншот из perfetto. Какие выводы ты можешь сделать?
#
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# ## 5. Haste (2 балла)
#
# Добавь `@jit` с разными возможными флагами для своего алгоритма из п. 1 или 3. Сравни скорость выполнения и точность.

# %%
# TODO

# %% [markdown]
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# ## 6. Polymorph (3 балла - для основы, ДПО и продвинутого потока)

# %% [markdown]
# Что такое библиотека `JAX`? Какой бонус она может дать для нас?
#
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# Напиши код QR-алгоритма из п. 1 или 3 при помощи `JAX`. Замерь время и точность - проанализируй их.

# %%
# TODO

# %% [markdown]
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# ## 7. Mass Cure Wounds (5 баллов)
#
#
# Используя познания, полученные в рамках пункта 2, перепиши параллельную версию алгоритма QR при помощи `multiprocessing`. Сравни точность и время с предыдущими версиями алгоритма.

# %%
# TODO

# %% [markdown]
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# Запусти с разными количествами процессов. Построй график. Какое число оптимально?

# %%
# TODO

# %% [markdown]
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# ## 8. Find the Path (5 баллов)
#
# Перепиши код QR из п. 6 на треды, используя `threading`.

# %%
# TODO

# %% [markdown]
# Получилось ли улучшить время работы программы? Почему?
#
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# ## 9. Power word stun (8 баллов)
#
# Перезапусти код из п. 8 под пересобранным питонами версий 3.13 и 3.14 с флагом `--disable-gil` так, чтобы использовалась фича снятия GIL.
#
#
# Так как это лучше делать не в рамках колаба (хотя если получится - то ОК), приложи к решению скриншоты запусков и код внизу.
#
# Проанализируй, как изменились время/точность работы программы. Влияет ли версия питона (3.13 или 3.14) на это?

# %%
# TODO

# %% [markdown]
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# ## 10. `Wish` (5 баллов).
#
# Собери все предыдущие реализации QR, затронутые (и реализованные) тобой в этой лабе и построй график скорости работы алгоритма в зависимости от размера матриц. Проанализируй его (и все свои выполненные действия).

# %%
# TODO

# %% [markdown]
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>
