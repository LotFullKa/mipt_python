# %% [markdown]
# <div style="text-align: center; padding: 30px 10px;">
#
# <h2 style="font-size: 30px; margin-top: 5px;">
# Лабораторная работа 6. PyTorch. Jax.
# </h2>
#
# <hr style="width: 60%; border: 1px solid #10069f; margin: 25px auto;">
#
# </div>
#
# Если Вы видите <b><font color="#FF69B4"> Ваш ответ здесь </font></b> - надо поменять текст внутри блока на свой текстовый ответ на вопрос.
#
#
# ВАЖНО! Здесь и далее от вас ожидается чистый код, близкий к тому, что нужно в индустрии. В контексте данной лабораторной работы ожидаются корректные названия у полей, методов и переменных, которые вы вводите; корректная инкапсуляция - нижнее подчеркивание или два перед названием метода или атрибута. Для корректной инкапсуляции можно (и даже нужно) добавлять нижние подчеркивания даже к названиям методов/атрибутов из условий задач :)
#
# ВАЖНО! Используйте корректные type hints :)

# %% [markdown]
# # 1. Tomb of `Ax = y`
#
# В прошлых лабораторных работах (прошлых жизнях) много внимания уделено решению системы линейных уравнений на питоне. Действительно, в задании 2.5 лабы 2 вы реализовывали свой метод наименьших квадратов.
#
# Из предыдущей лабы (лабы 5) можно догадаться, что мы не просто так научились генерировать x, y и подматрицы. В данном домашнем задании мы попробуем подобрать наилучшее решение для системы линейных уравнений.
#
#
# Но для начала нам надо сравнить, чем воспользоваться. Возьмите код из лабы 5 с генерацией x, y. Возьмите код `my_lsq` из задания 2.5 лабы 2. Возьмите код разложений из лабы 3 (в частности, Cholesky и QR).
#
# Сравните ниже их применимость (по времени и точности) для аппроксимации решения СЛАУ Ax = y, где A - матрица из $n$ строк и $m$ столбцов, где $n >> m$.
#
# P.S. Понятно, что у такой системы (скорее всего) не будет решения. Нам достаточно найти $\text{argmin}_x (||Ax - y||_2)$.

# %%
# TODO

# %% [markdown]
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# ## 2. The Wild Beyond The `PyTorch`
#
# Возьми алгоритм QR из предыдущего пункта. Перенеси его на `PyTorch`. Сравни по скорости и точности со своим предыдущим QR.

# %%
# TODO

# %% [markdown]
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# ## 3. The `Jax` Beyond the Witchlight
#
#
# Возьми алгоритм QR из п.1. Перенеси его на библиотеку Jax. Сравни по скорости и точности с предыдущими двумя имплементациями QR. Сделай выводы.

# %%
# TODO

# %% [markdown]
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# ## 4. `OMP` of the Abyss
#
#
# Дело осталось за немногим!
#
# Скопируй код из домашнего задания номер 5 (про генерацию x, y и различных векторов/подматриц).
#
#
# Реализуй следующий алгоритм на его основе и используя версию на PyTorch из п. 2:
#
# Given: $k \in \mathbb{N}$:
#
# $r = y$
#
# FOR $i$ IN range($k$):
#
# $\quad$ curr_delta$ = \infty$
#
# $\quad$ $M_\text{best}$ = None
#
# $\quad$ FOR $M$ IN matrices:
#
# $\quad$ $\quad$ FIND $x_{\text{mat}}$: $M x_{\text{mat}} = r$
#
# $\quad$ $\quad$ IF curr_delta $< ||r - M x_{\text{mat}}||_2$:
#
# $\quad$ $\quad$ $\quad$ curr_delta $= ||r - M x_{\text{mat}}||_2$
#
# $\quad$ $\quad$ $\quad$ $M_\text{best} = M$
#
# $\quad$ DELETE $M_\text{best} = M$ FROM matrices
#
# $\quad$ $r = r - M x_{\text{mat}}$

# %%
# TODO

# %% [markdown]
# Построй график зависимости $||r||_2$ от итерации (i)

# %%
# TODO

# %% [markdown]
# Проанализируй график
#
#
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# # 5. Waterdeep: `Traces` of the Mad Mage
#
# Запусти трейсы для кода из п. 4. Визуализируй через perfetto.
#
# Этот ноутбук, трейсы и скриншот перфетто сложи в zip, который загрузишь в формочку, а здесь напиши выводы, которые ты можешь сделать из трейсов.

# %%
# TODO

# %% [markdown]
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>
