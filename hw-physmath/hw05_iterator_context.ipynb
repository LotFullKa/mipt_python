# %% [markdown]
# <div style="text-align: center; padding: 30px 10px;">
#
# <h2 style="font-size: 30px; margin-top: 5px;">
# Лабораторная работа 5. Итераторы, генераторы, контекстные менеджеры.
# </h2>
#
# <hr style="width: 60%; border: 1px solid #10069f; margin: 25px auto;">
#
# </div>
#
# Если Вы видите <b><font color="#FF69B4"> Ваш ответ здесь </font></b> - надо поменять текст внутри блока на свой текстовый ответ на вопрос.
#
#
# ВАЖНО! Здесь и далее от вас ожидается чистый код, близкий к тому, что нужно в индустрии. В контексте данной лабораторной работы ожидаются корректные названия у полей, методов и переменных, которые вы вводите; корректная инкапсуляция - нижнее подчеркивание или два перед названием метода или атрибута. Для корректной инкапсуляции можно (и даже нужно) добавлять нижние подчеркивания даже к названиям методов/атрибутов из условий задач :)
#
# ВАЖНО! Используйте корректные type hints :)

# %% [markdown]
# В этой лабе мы создадим вспомогательный класс для работы с функциями - `DataManager`.

# %% [markdown]
# ## Часть 1. `DataManager` wears Prada.
#
# Сделайте простенький `__init__`, который принимает на вход `x_method` - метод, которым будет создаваться некий вектор х.
#
# Метода будет два:
#
# 1. Из файла - тогда надо будет передать `file_path`. Тип полученного файла - .dat.
#
# 2. Случайные числа. Нужно будет нагенерировать `n` случайных комплексных чисел. Границы задайте сами (скажем, числа должны быть по модулю не более `r`).

# %%
# TODO

# %%
# Протестируй свой код

# %% [markdown]
# ## Часть 2. The `f(x) = y` diaries.
#
# Теперь мы хотим сделать метод `generate_y`. Опять, у нас будет 3 способа генерации $y$:
#
# 1. Из файла (и нам нужно будет передать путь до файла с $y$ и проверить, что длина $y$ равна длине $х$).
#
# 2. Мы передаём на вход некие коэффициенты, степень полинома и максимальную задержку, которая может быть, т.е. по сути для $x_n$ $y_n = f(x_n, x_{n-1}, x_{n-2}, \dots, x_{n-m})$, где $f$ - многочлен степени $p$.
#
# 3. Случайная генерация коэффициентов - на вход передаются задержка $m$, степень $p$, максимальная величина коэффициента $\gamma$. Коэффициенты генерируются случайные.

# %% [markdown]
# Какой будет самый логичный и красивый способ передать параметры многочлена в п. 2?
#
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# Где надо будет брать модуль от комплексного числа?
#
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %%
# TODO

# %%
# Протестируй свой код

# %% [markdown]
# ## Часть 3. `Iterator` Mary
#
# Наша ультимативная задача теперь - нагенерировать все возможные полиномы красиво. Давайте сделаем функции:
#
# - `generate_v1`, которая на вход принимает четыре значения $m_1$, $m_2$, $p_1$, $p_2$, где $m_i$ - задержки (если был ($x_1$ $x_2$ $x_3$ ... $x_{n-1}$ $x_n$), то при задержке 2 этот вектор будет выглядеть ($0$ $0$ $x_1$ ... $x_{n-3}$ $x_{n-2}$)), и возвращает $x_{m_1}^{p_1} \cdot x_{m_2}^{p_2}$
#
# - `generate_v2`, которая на вход принимает $m_1$, $m_2$, $p$, где $m_i$ тоже задержки, и возвращает матрицу из $p+1$ столбцов, где $i$-й столбец это $x_{m_1}^i \cdot x_{m_2}$
#
# Также напишите два итератора:
#
# - `iter_v1` - класс-итератор, который итерируется по всем возможным значениям за исключением тех, которые сохранены в список `banned_v1` (атрибут объекта)
#
# - `iter_v2` - генератор-итератор, который итерируется по всем возможным значениям за исключением тех, которые сохранены в список `banned_v2` (атрибут объекта)

# %%
# TODO

# %%
# Протестируй свой код

# %% [markdown]
# ## 4. Алиса в стране `Context Manager`
#
# Сравни две реализации контекстного менеджера - через `@contextmanager` и через `__enter__`, `__exit__`. Какой лучше?
#
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# Реализуй контекстный менеджер, чтобы открывались ваши файлы, в которых хранятся $х$ и $y$, и при выходе из контекстного менеджера сохраняет туда итоговые значения.

# %%
# TODO

# %%
# Протестируй свой код

# %% [markdown]
# P.S. Кому интересно - наша цель в этой лабе - научиться аппроксимировать сложную функцию с эффектом памяти. Обычные ряды Тейлора для этого не подходят, для этого есть ряды Вольтерра. Тут мы сейчас по своей сути делаем ряды Вольтерра в дискретном виде - способов ввести базис довольно много, приведены два каких-то :)
