# %% [markdown]
# <h2 style="font-size: 30px; margin-top: 5px;">
# Бонусная лабораторная работа 1. Написание Jupyter extensions в Google Colab
# </h2>
#
# <hr style="width: 60%; border: 1px solid #10069f; margin: 25px auto;">
#
# </div>
#
# Если Вы видите <b><font color="#FF69B4"> Ваш ответ здесь </font></b> - надо поменять текст внутри блока на свой текстовый ответ на вопрос.
#
#
# **ВАЖНО!** В данной лабораторной работе от вас требуется:
# - Написать работающие Jupyter extension-ы
# - Протестировать их в Google Colab
# - Оформить код в соответствии с PEP 8
# - Добавить документацию (docstring) ко всем функциям
# - Написать примеры использования расширений, если имеющихся тестов **недостаточно** для тестирования полного описанного функционала

# %% [markdown]
# ## Задача 1. Базовые Magic-команды (2 балла)
#
# ### 1.1. Line magic для работы с переменными (0.5 балла)
#
# Реализуйте line magic `%inspect`, которая принимает имя переменной и выводит информацию о ней:
# - Тип переменной
# - Размер (если применимо: для строк, списков, массивов)
# - Первые 5 элементов (для коллекций)
#
# **Требования:**
# - Используйте декоратор `@register_line_magic`
# - Обработайте случай, когда переменная не существует
# - Для numpy массивов выводите shape и dtype

# %%
from IPython.core.magic import register_line_magic
import numpy as np

@register_line_magic
def inspect(line):
    """
    Inspect a variable and display its type, size, and preview.

    Usage: %inspect variable_name

    Args:
        line: Name of the variable to inspect

    Returns:
        None: Prints variable information
    """
    # TODO: implement inspection logic
    pass

# Тесты
test_int = 42
test_list = [1, 2, 3, 4, 5, 6, 7]
test_string = "Hello, World! This is a test string."
test_array = np.random.rand(10, 10)

# %inspect test_int
# %inspect test_list
# %inspect test_string
# %inspect test_array
# %inspect nonexistent_var  # Должно вывести ошибку

# %% [markdown]
# ### 1.2. Cell magic для измерения памяти (0.5 балла)
#
# Реализуйте cell magic `%%memprofile`, которая:
# - Замеряет использование памяти до и после выполнения кода
# - Выводит разницу в потреблении памяти
# - Опционально выводит список созданных переменных и их размер

# %%
from IPython.core.magic import register_cell_magic
import tracemalloc

@register_cell_magic
def memprofile(line, cell):
    """
    Profile memory usage of code execution.

    Usage: %%memprofile [--verbose]

    Args:
        line: Command line arguments (--verbose for detailed output)
        cell: Code to execute and profile

    Returns:
        None: Prints memory usage statistics
    """
    # TODO: implement memory profiling
    pass

# Тесты(запуск должен быть в отдельных ячейках)
# %%memprofile
large_list = list(range(1000000))
large_array = [x ** 2 for x in large_list]

# %%memprofile --verbose
import numpy as np
matrix = np.random.rand(1000, 1000)
result = np.linalg.inv(matrix)

# %% [markdown]
# ### 1.3. Line/Cell magic универсальная (1 балл)
#
# Реализуйте magic `%%snippet` (работает и как line, и как cell), которая:
# - Сохраняет код в библиотеку сниппетов
# - Позволяет загружать сохранённые сниппеты по имени
# - Поддерживает команды: `save <name>`, `load <name>`, `list`, `delete <name>`
#
# **Требования:**
# - Сниппеты сохраняются в словаре или файле
# - При загрузке сниппет выполняется в текущей ячейке
# - Команда `list` показывает все сохранённые сниппеты

# %%
from IPython.core.magic import register_line_cell_magic
import json
import os

# Глобальное хранилище сниппетов
SNIPPETS_FILE = '/content/snippets.json'

@register_line_cell_magic
def snippet(line, cell=None):
    """
    Manage code snippets library.

    Usage:
        # %%snippet save <name>
        code to save

        # %snippet load <name>
        # %snippet list
        # %snippet delete <name>

    Args:
        line: Command and arguments
        cell: Code to save (for save command)

    Returns:
        None: Performs snippet operations
    """
    # TODO: implement snippet management
    pass

# Тесты(запуск в отдельных ячейках)
# %%snippet save data_loader
import pandas as pd
def load_data(path):
    return pd.read_csv(path)

# %snippet list

# %snippet load data_loader

# %snippet delete data_loader

# %% [markdown]
# ## Задача 2. Расширения для работы с данными (3 балла)
#
# ### 2.1. Magic для автоматической визуализации DataFrame (1 балл)
#
# Реализуйте line magic `%dfplot`, которая:
# - Принимает имя DataFrame и тип графика
# - Автоматически выбирает колонки для осей X и Y
# - Поддерживает типы: `line`, `bar`, `scatter`, `hist`, `box`
# - Добавляет заголовок, подписи осей, сетку
#
# **Требования:**
# - Используйте argparse для парсинга аргументов
# - Обработайте случаи, когда DataFrame не существует или пуст
# - Для гистограмм автоматически выбирайте число bins

# %%
from IPython.core.magic import register_cell_magic
from IPython.core.magic_arguments import magic_arguments, argument, parse_argstring
import time
import statistics
import pandas as pd
import matplotlib.pyplot as plt

@magic_arguments()
@argument('df_name', help='Name of the DataFrame')
@argument('-t', '--type', choices=['line', 'bar', 'scatter', 'hist', 'box'], default='line', help='Plot type')
@argument('-x', '--x', type=str, default=None, help='Column for X axis')
@argument('-y', '--y', type=str, default=None, help='Column for Y axis')
@argument('--title', type=str, default=None, help='Plot title')
@argument('--figsize', type=str, default='10,6', help='Figure size as width,height')
@register_line_magic
def dfplot(line):
    """
    Quick plot for pandas DataFrame.

    Usage: %dfplot df_name [-t TYPE] [-x X_COL] [-y Y_COL] [--title TITLE]

    Args:
        line: Command line arguments

    Returns:
        None: Displays the plot
    """
    # TODO: implement DataFrame plotting
    pass

# Тесты (запуск в отдельной ячейке)
df = pd.DataFrame({
    'date': pd.date_range('2024-01-01', periods=100),
    'value': np.random.randn(100).cumsum() + 100,
    'category': np.random.choice(['A', 'B', 'C'], 100),
    'score': np.random.randint(0, 100, 100)
})

# %dfplot df -t line -x date -y value --title "Time Series"
# %dfplot df -t scatter -x value -y score
# %dfplot df -t box -y score

# %% [markdown]
# ### 2.2. Magic для экспорта/импорта данных (1 балл)
#
# Реализуйте line magic `%dataio`, которая поддерживает операции:
# - `export <var_name> <format> <path>` - экспорт переменной
# - `import <var_name> <format> <path>` - импорт в переменную
# - Поддерживаемые форматы: `csv`, `json`, `pickle`, `npy`
#
# **Требования:**
# - Автоопределение формата по расширению файла, если не указан
# - Обработка ошибок при отсутствии файла или переменной
# - Для pickle/npy используйте соответствующие библиотеки

# %%
from IPython.core.magic import register_line_magic
import pandas as pd
import numpy as np
import pickle
import json

@register_line_magic
def dataio(line):
    """
    Import/Export data in various formats.

    Usage:
        # %dataio export var_name format path
        # %dataio import var_name format path

    Supported formats: csv, json, pickle, npy

    Args:
        line: Command with operation, variable name, format, and path

    Returns:
        None: Performs I/O operation
    """
    # TODO: implement data I/O
    pass

# Тесты
test_df = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
test_array = np.random.rand(5, 5)
test_dict = {'key': 'value', 'number': 42}

# %dataio export test_df csv /content/test_df.csv
# %dataio export test_array npy /content/test_array.npy
# %dataio export test_dict json /content/test_dict.json

# %dataio import loaded_df csv /content/test_df.csv
# %dataio import loaded_array npy /content/test_array.npy
# %dataio import loaded_dict json /content/test_dict.json

print("Loaded DataFrame:")
print(loaded_df)
print("\nLoaded Array shape:", loaded_array.shape)
print("\nLoaded Dict:", loaded_dict)

# %% [markdown]
# ### 2.3. Cell magic для повторяющихся экспериментов (1 балл)
#
# Реализуйте cell magic `%%experiment`, которая:
# - Выполняет код ячейки N раз
# - Собирает статистику по времени выполнения
# - Сохраняет результаты каждой итерации
# - Выводит summary: mean, std, min, max время
# - Опционально сохраняет все результаты в переменную
#
# **Требования:**
# - Аргументы: количество итераций, имя переменной для результатов
# - Обработка исключений в каждой итерации
# - Вывод прогресса выполнения

# %%
from IPython.core.magic import register_cell_magic
from IPython.core.magic_arguments import magic_arguments, argument, parse_argstring
import time
import statistics
import sys

@magic_arguments()
@argument('n_iterations', type=int, help='Number of iterations')
@argument('-o', '--output', type=str, default=None, help='Variable name to store results')
@argument('--skip-errors', action='store_true', help='Continue on errors')
@register_cell_magic
def experiment(line, cell):
    """
    Run code multiple times and collect statistics.

    Usage: %%experiment N [-o OUTPUT_VAR] [--skip-errors]

    Args:
        line: Command line arguments
        cell: Code to execute repeatedly

    Returns:
        None: Prints statistics and optionally stores results
    """
    # TODO: implement experiment runner
    pass

# Тесты
# %%experiment 5 -o exp_results
import random
import time
time.sleep(random.uniform(0.1, 0.3))
result = random.randint(1, 100)
print(f"Iteration result: {result}")

print(f"\nStored results: {exp_results}")

# %% [markdown]
# ## Задача 3. IPython Extension модуль (3 балла)
#
# Создайте полноценный IPython extension модуль `colab_tools.py`, который включает:
#
# ### 3.1. Минимум 2 magic-команды разных типов (1.5 балла)
#
# Придумайте и реализуйте 2+ полезные magic-команды на ваш выбор. Примеры идей:
# - `%gitcmd` - выполнение git команд прямо из ноутбука
# - `%%sqllite` - выполнение SQL запросов к SQLite базе
# - `%envmanager` - управление переменными окружения
# - `%%retry` - повторное выполнение кода при ошибках
# - `%compare` - сравнение двух переменных
#
# **Требования:**
# - Каждая команда должна иметь docstring
# - Должна быть обработка ошибок
# - К каждой команде должны быть примеры использования

# %%
# Создайте файл colab_tools.py со следующим содержимым:

extension_code = '''
"""
Colab Tools - Custom IPython Extension

This module provides custom magic commands for Google Colab environment.
"""

from IPython.core.magic import register_line_magic, register_cell_magic
from IPython.core.magic_arguments import magic_arguments, argument, parse_argstring
import os
import sys
import subprocess

# TODO: Implement your 2+ magic commands here
# Magic command 1:

# Magic command 2:

# Magic command 3(optional):

def load_ipython_extension(ipython):
    """
    Load the extension.

    This function is called when the extension is loaded via %load_ext.
    Magic commands are automatically registered via decorators.

    Args:
        ipython: IPython shell instance
    """
    print("Colab Tools extension loaded successfully!")
    print("Available commands: %list_commands")

def unload_ipython_extension(ipython):
    """
    Unload the extension.

    Args:
        ipython: IPython shell instance
    """
    print("Colab Tools extension unloaded.")
'''

# Сохраните файл
with open('/content/colab_tools.py', 'w') as f:
    f.write(extension_code)

print("Extension file created: /content/colab_tools.py")

# Теперь загрузите расширение и протестируйте:
# %load_ext colab_tools

# %% [markdown]
# ### 3.3. Тестирование расширения (1.5 балла)
#
# Напишите тесты для вашего расширения:
# - Проверьте работу каждой magic-команды
# - Проверьте обработку ошибок
# - Проверьте загрузку/выгрузку расширения
#
# **Требования:**
# - Минимум 5 тестовых случаев
# - Используйте assert для проверок
# - Добавьте комментарии к тестам

# %%
# Тесты для расширения
# TODO: Write at least 5 test cases

# Test 1:

# Test 2:

# Test 3:

# Test 4:

# Test 5:

print("✅ All tests passed!")

# %% [markdown]
# # Выводы (1 балл)

# %% [markdown]
# В конце ответьте на вопросы:
# - Какие задачи упрощают разработанные вами magic-команды? <b><font color="#FF69B4"> Ваш ответ здесь </font></b>
#
# - Когда стоит создавать своё расширение? <b><font color="#FF69B4"> Ваш ответ здесь </font></b>
#
# - Какие задачи НЕ стоит решать с помощью magic-команд? <b><font color="#FF69B4"> Ваш ответ здесь </font></b>
