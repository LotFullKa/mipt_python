# %% [markdown]
# <div style="text-align: center; padding: 30px 10px;">
#
# <h2 style="font-size: 30px; margin-top: 5px;">
# Лабораторная работа 6. Asyncio. Multiprocessing.
# </h2>
#
# <hr style="width: 60%; border: 1px solid #10069f; margin: 25px auto;">
#
# </div>
#
#
# Если Вы видите <b><font color="#FF69B4"> Ваш ответ здесь </font></b> - надо поменять текст внутри блока на свой текстовый ответ на вопрос.
#
#
# ВАЖНО! Здесь и далее от вас ожидается чистый код, близкий к тому, что нужно в индустрии. В контексте данной лабораторной работы ожидаются корректные названия у полей, методов и переменных, которые вы вводите; корректная инкапсуляция - нижнее подчеркивание или два перед названием метода или атрибута. Для корректной инкапсуляции можно (и даже нужно) добавлять нижние подчеркивания даже к названиям методов/атрибутов из условий задач :)
#
#
# ВАЖНО! В функциях необходимо указывать корректные type hints.

# %% [markdown]
# ## 1. The `Requests` of Tiamat (3 балла).
#
#
# Знаменитое многоглавое драконье божество Тиамат имеет несколько голов, благодаря чему умеет делать несколько HTTP запросов одновременно. Мы так (пока что) не умеем, но в рамках данной лабораторной работы можем попробовать научиться.
#
# Выбери сайт для парсинга и напиши четыре функции (частично можно скопировать из предыдущего дз):
#
# - `parse_func(html_text)` - некая функция для парсинга странички вашего сайта
#
# - `sync_request_no_session(url, parse_func)` - синхронное обращение к сайту, которое возвращает обработанное значение со странички сайта по ссылке
#
# - `sync_request_session(url, session, parse_func)` - синхронное обращение к сайту в рамках одной (переданной) сессии
#
# - `async_request(url, session, parse_func)` - асинхронное обращение к сайту в рамках одной (переданной) сессии

# %%
# TODO

# %%
# TODO - запустите примеры

# %% [markdown]
# ## 2. Tasha's Cauldron of `Parsing` (2 балла).
#
# Напишите функции
#
#  - `sync_parse_urls(urls)`
#
#  - `sync_parse_urls_v2(urls)`
#
#  - `async_parse_urls(urls)`
#
#  Все 3 функции принимают на вход список ссылок и получают информацию с каждой из них, после чего вся собранная информация собирается в датафрейм, который и возвращается функцией.

# %%
# TODO

# %%
# TODO - запустите примеры

# %% [markdown]
# Сделайте замеры по времени. Какая быстрее? Почему?
#
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# ## 3. Icewind Dale: `Semaphor` of the Frostmaiden (5 баллов).
#
# Добавьте в `async_request` и `sync_request_session` счётчики для одновременно запущенных функций.
#
# Нарисуйте график количества запущенных функций от времени.

# %%
# TODO

# %% [markdown]
# Напишите функции `async_reqest_with_semaphor` и `async_parse_urls_with_semaphor`. Получите значения при 3-х разных k (максимальных количествах в семафоре). Перестройте график с разными способами парсинга из п. 2.

# %%
# TODO

# %% [markdown]
# Какие выводы из графика можно сделать?
#
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# ## 4. Waterdeep: `Multiprocessing` of the Mad Mage (5 баллов).
#
# Добавь функцию `multiprocess_parse_urls(urls, num_workers)`. Построй график времени парсинга в зависимости от числа рабочих.

# %%
# TODO

# %% [markdown]
# Какой вывод из графика мы можем сделать?
#
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# Добавь лучший и худший результаты мультипроцессинга на график из п. 2-3.

# %%
# TODO

# %% [markdown]
# Сможем ли мы так же сделать простую переменную для отслеживания количества запущенных функций за раз в случае мультипроцессинга?
#
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>
